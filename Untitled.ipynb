# %%
# Dependencies and Setup
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts

# Study data files
mouse_metadata = "data/Mouse_metadata.csv"
study_results = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata)
study_results = pd.read_csv(study_results)
mouse_metadata.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0     k403     Ramicane    Male          21          16
# 1     s185    Capomulin  Female           3          17
# 2     x401    Capomulin  Female          16          15
# 3     m601    Capomulin    Male          22          17
# 4     g791     Ramicane    Male          11          16

# %%
study_results
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
# Combine the data into a single dataset
merged_data_df = pd.merge(study_results, mouse_metadata, how="left", on=["Mouse ID", "Mouse ID"])
merged_data_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# 0     Female           9          22
# 1       Male          15          29
# 2     Female           2          29
# 3     Female          11          30
# 4       Male          21          25
# ...      ...         ...         ...
# 1888    Male          12          25
# 1889    Male          18          17
# 1890  Female          11          26
# 1891  Female          21          30
# 1892  Female           4          26
#
# [1893 rows x 8 columns]

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
group_data_df = merged_data_df.groupby(["Drug Regimen"])
group_data_df.count()
# Out:
#               Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites  Sex  \
# Drug Regimen
# Capomulin          230        230                 230               230  230
# Ceftamin           178        178                 178               178  178
# Infubinol          178        178                 178               178  178
# Ketapril           188        188                 188               188  188
# Naftisol           186        186                 186               186  186
# Placebo            181        181                 181               181  181
# Propriva           161        161                 161               161  161
# Ramicane           228        228                 228               228  228
# Stelasyn           181        181                 181               181  181
# Zoniferol          182        182                 182               182  182
#
#               Age_months  Weight (g)
# Drug Regimen
# Capomulin            230         230
# Ceftamin             178         178
# Infubinol            178         178
# Ketapril             188         188
# Naftisol             186         186
# Placebo              181         181
# Propriva             161         161
# Ramicane             228         228
# Stelasyn             181         181
# Zoniferol            182         182

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
group_data_df = merged_data_df.groupby(["Drug Regimen"])
group_data_df.count().head()

mean = group_data_df["Tumor Volume (mm3)"].mean()

median = group_data_df["Tumor Volume (mm3)"].median()

tumor_vol = group_data_df["Tumor Volume (mm3)"]
mode = sts.mode(tumor_vol)
mode
#mode = group_data_df["Tumor Volume (mm3)"].mode()
#mean_numpy = np.mean(merge_data)
#mean_numpy

#Calculating the summary of statistics
#stats_df = pd.DataFrame({"Mean Tumor Volume":mean, "Median Tumor Volume":median})
#stats_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-dece6b95d7bb> in <module>
#       8
#       9 tumor_vol = group_data_df["Tumor Volume (mm3)"]
# ---> 10 mode = sts.mode(tumor_vol)
#      11 mode
#      12 #mode = group_data_df["Tumor Volume (mm3)"].mode()
#
# ~\Anaconda3\lib\site-packages\scipy\stats\stats.py in mode(a, axis, nan_policy)
#     456         return mstats_basic.mode(a, axis)
#     457
# --> 458     if a.dtype == object and np.nan in set(a.ravel()):
#     459         # Fall back to a slower method since np.unique does not work with NaN
#     460         scores = set(np.ravel(a))  # get ALL unique values
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1884         raise TypeError(
#    1885             "{0!r} objects are mutable, thus they cannot be"
# -> 1886             " hashed".format(self.__class__.__name__)
#    1887         )
#    1888
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed
