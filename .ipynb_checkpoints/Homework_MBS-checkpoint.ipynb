# %%
# Dependencies and Setup
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as stats

# Study data files
mouse_metadata = "data/Mouse_metadata.csv"
study_results = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata)
study_results = pd.read_csv(study_results)
#print(f"metadata: {mouse_metadata.shape}, study: {study_results.shape}")
mouse_metadata
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0       k403     Ramicane    Male          21          16
# 1       s185    Capomulin  Female           3          17
# 2       x401    Capomulin  Female          16          15
# 3       m601    Capomulin    Male          22          17
# 4       g791     Ramicane    Male          11          16
# ..       ...          ...     ...         ...         ...
# 244     z314     Stelasyn  Female          21          28
# 245     z435     Propriva  Female          12          26
# 246     z581    Infubinol  Female          24          25
# 247     z795     Naftisol  Female          13          29
# 248     z969     Naftisol    Male           9          30
#
# [249 rows x 5 columns]

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
study_results
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
# Combine the data into a single dataset
merged_data_df = pd.merge(study_results, mouse_metadata, how="left", on="Mouse ID")
merged_data_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
group_data_df = merged_data_df.groupby(["Drug Regimen"])
group_data_df.count()
# Out:
#               Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites  Sex  \
# Drug Regimen
# Capomulin          230        230                 230               230  230
# Ceftamin           178        178                 178               178  178
# Infubinol          178        178                 178               178  178
# Ketapril           188        188                 188               188  188
# Naftisol           186        186                 186               186  186
# Placebo            181        181                 181               181  181
# Propriva           161        161                 161               161  161
# Ramicane           228        228                 228               228  228
# Stelasyn           181        181                 181               181  181
# Zoniferol          182        182                 182               182  182
#
#               Age_months  Weight (g)
# Drug Regimen
# Capomulin            230         230
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
group_data_df = merged_data_df.groupby(["Drug Regimen"])
group_data_df.count().head()

mean = group_data_df["Tumor Volume (mm3)"].mean()

median = group_data_df["Tumor Volume (mm3)"].median()

var = group_data_df["Tumor Volume (mm3)"].var()

std_dev = group_data_df["Tumor Volume (mm3)"].std()

std_err = group_data_df["Tumor Volume (mm3)"].sem()
#mode = group_data_df["Tumor Volume (mm3)"].mode()
#mean_numpy = np.mean(merge_data)
#mean_numpy

#Calculating the summary of statistics
stats_df = pd.DataFrame({"Mean Tumor Volume":mean, "Median Tumor Volume":median, "Tumor Volume Variance":var, 
                         "Tumor Volume Std. Dev":std_dev, "Tumor Volume Std. Err":std_err})
stats_df
# Out:
#               Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites  Sex  \
# Drug Regimen
# Capomulin          230        230                 230               230  230
# Ceftamin           178        178                 178               178  178
# Infubinol          178        178                 178               178  178
# Ketapril           188        188                 188               188  188
# Naftisol           186        186                 186               186  186
#
#               Age_months  Weight (g)
# Drug Regimen
# Capomulin            230         230
# Ceftamin             178         178
# Infubinol            178         178
# Ketapril             188         188
# Naftisol             186         186
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# ...

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pandas

count = group_data_df["Tumor Volume (mm3)"].count()

treat_reg_df = pd.DataFrame({"Data Points":count})
treat_sorted_df = treat_reg_df.sort_values("Data Points", ascending=False)

#Colors of the bar plot
#colors = ["blue", "pink", "red", "orange", "purple", "green", "grey", "light_blue", "yellow", "black"]
treat_sorted_df
# Out:
#               Data Points
# Drug Regimen
# Capomulin             230
# Ramicane              228
# Ketapril              188
# Naftisol              186
# Zoniferol             182
# Placebo               181
# Stelasyn              181
# Ceftamin              178
# Infubinol             178
# Propriva              161

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pandas
treat_sorted_df.plot(kind="bar", color="red",figsize=(6,4.5),legend=False, align="center")

# Aesthetics for the chart
plt.title("Treatment Regimen")
plt.ylabel("Number of Data Points")
plt.xlim(-.5,9.5)
plt.show()

#Saving an image of this plot
plt.savefig("Images/3-Pandas_DrugRegimen.png")
# Out:
# Text(0.5, 1.0, 'Treatment Regimen')
# Text(0, 0.5, 'Number of Data Points')
# (-0.5, 9.5)

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pyplot
#Defining x and y
x_axis = treat_sorted_df.index
y_axis = treat_sorted_df["Data Points"]

#Plotting with pyplot
plt.bar(x_axis, y_axis, color='r', align="center", width=0.6)

# Aesthetics for the chart

plt.xticks(x_axis,rotation=90)
plt.title("Treatment Regimen")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Data Points")
plt.xlim(-.75,)
plt.show()

#Saving an image of this plot
plt.savefig("Images/4-Pyplot_DrugRegimen.png")
# Out:
# <BarContainer object of 10 artists>
# ([<matplotlib.axis.XTick at 0x1b19a80eb48>,
# ...
#  <a list of 10 Text xticklabel objects>)
# Text(0.5, 1.0, 'Treatment Regimen')
# Text(0.5, 0, 'Drug Regimen')
# Text(0, 0.5, 'Number of Data Points')
# (-0.75, 9.78)

# %%
#Generate a pie plot showing the distribution of female versus male mice using pandas

#Prepare data to be plotted
#Group the initial merged DataFrame by sex

sex_group_df = merged_data_df.groupby(["Mouse ID"])
gender = sex_group_df['Sex'].first()
sex_group_df.head()
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1107     x401         20           36.065835                 0    Capomulin
# 1108     m269         20           61.145866                 0     Stelasyn
# 1109     a963         20           51.463734                 0     Stelasyn
# 1110     p189         20           56.530204                 3     Ketapril
# 1112     n304         20           49.253309                 1     Naftisol
#
#          Sex  Age_months  Weight (g)
# ...

# %%
sex_group_df

# %%
#Create a DataFrame to capture gender data
sex_data_df = pd.DataFrame({"Sex":gender})
#Tells matplotlib to seperate the both gender sections from the each others
explode = (0.04, 0)

#Color to be displayed
colors = ["purple", "green"]
genders = sex_data_df['Sex'].value_counts()
sex_data_df
#genders
# Out:
#              Sex
# Mouse ID
# a203      Female
# a251      Female
# a262      Female
# a275      Female
# a366      Female
# ...          ...
# z435      Female
# z578        Male
# z581      Female
# z795      Female
# z969        Male
#
# [249 rows x 1 columns]

# %%
genders.plot(kind="pie", explode=explode, colors = colors, subplots=True, autopct='%1.1f%%',figsize=(5,5))

plt.title("Gender Distribution")
plt.ylabel("Sex")
plt.show()

#Saving an image of this plot
plt.savefig("Images/5-Pandas Gender Distribution.png")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001B19A8A4048>],
#       dtype=object)
# Text(0.5, 1.0, 'Gender Distribution')
# Text(0, 0.5, 'Sex')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(genders, explode=explode, colors=colors,
        autopct="%1.2f%%")

plt.title("Gender Distribution")
plt.xlabel("Female")
plt.ylabel("Sex")
fig = plt.gcf()
fig.set_size_inches(5,5)
plt.show()

#Saving an image of this plot
plt.savefig("Images/6-Pyplot Gender Distribution.png")
# Out:
# ([<matplotlib.patches.Wedge at 0x1b19a91f888>,
# ...
#  [Text(-0.007191509648648046, 1.1399773165238745, ''),
#   Text(0.006939175976765524, -1.0999781124353174, '')],
#  [Text(-0.004037338750118201, 0.6399872654169118, '50.20%'),
#   Text(0.00378500507823574, -0.5999880613283548, '49.80%')])
# Text(0.5, 1.0, 'Gender Distribution')
# Text(0.5, 0, 'Female')
# Text(0, 0.5, 'Sex')

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens.
# Calculate the IQR and quantitatively determine if there are any potential outliers. 

#Determine final tumor volume values 
merged_data_df
#Sort the merged data DF by Timepoint and group by Mouse ID
mouse_group = merged_data_df.sort_values("Timepoint", ascending=False).groupby(["Mouse ID"])

fin_tumor = mouse_group["Tumor Volume (mm3)"].first()
regimen = mouse_group["Drug Regimen"].first()

regimen_df = pd.DataFrame({"Tumor Volume (mm3)":fin_tumor, "Drug Regimen":regimen})
regimen_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        f932          0           45.000000                 0     Ketapril
# 2        g107          0           45.000000                 0     Ketapril
# 3        a457          0           45.000000                 0     Ketapril
# 4        c819          0           45.000000                 0     Ketapril
# ...       ...        ...                 ...               ...          ...
# 1888     r944         45           41.581521                 2    Capomulin
# 1889     u364         45           31.023923                 3    Capomulin
# 1890     p438         45           61.433892                 1     Ceftamin
# 1891     x773         45           58.634971                 4      Placebo
# 1892     b879         45           72.555239                 2     Stelasyn
#
#          Sex  Age_months  Weight (g)
# ...

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens.
# Calculate the IQR and quantitatively determine if there are any potential outliers. 

capomulin = regimen_df.loc[regimen_df["Drug Regimen"] == "Capomulin", ["Tumor Volume (mm3)"]]["Tumor Volume (mm3)"].quantile([0,0.25,0.5])
ramicane = regimen_df.loc[regimen_df["Drug Regimen"] == "Ramicane", ["Tumor Volume (mm3)"]]["Tumor Volume (mm3)"].quantile([0,0.25,0.5])
infubinol = regimen_df.loc[regimen_df["Drug Regimen"] == "Infubinol", ["Tumor Volume (mm3)"]]["Tumor Volume (mm3)"].quantile([0,0.25,0.5])
ceftamin = regimen_df.loc[regimen_df["Drug Regimen"] == "Ceftamin", ["Tumor Volume (mm3)"]]["Tumor Volume (mm3)"].quantile([0,0.25,0.5])

promising_reg_df = pd.DataFrame({"Capomulin Tumor Vol (mm3)":capomulin,"Ramicane Tumor Vol (mm3)":ramicane, 
                                 "Infubinol Tumor Vol (mm3)":infubinol, "Ceftamin Tumor Vol (mm3)":ceftamin})
promising_reg_df.index.name = "Quantiles"
promising_reg_df
# ramicane
# infubinol
# ceftamin
# capomulin
# Out:
#            Capomulin Tumor Vol (mm3)  Ramicane Tumor Vol (mm3)  \
# Quantiles
# 0.00                       23.343598                 22.050126
# 0.25                       32.377357                 31.560470
# 0.50                       38.125164                 36.561652
#
#            Infubinol Tumor Vol (mm3)  Ceftamin Tumor Vol (mm3)
# Quantiles
# 0.00                       36.321346                 45.000000
# 0.25                       54.048608                 48.722078
# 0.50                       60.165180                 59.851956

# %%
#Create a combined data frame of all promising drug regimes
my_capomulin = regimen_df.loc[regimen_df["Drug Regimen"] == "Capomulin", ["Tumor Volume (mm3)"]]["Tumor Volume (mm3)"].tolist()
my_ramicane = regimen_df.loc[regimen_df["Drug Regimen"] == "Ramicane", ["Tumor Volume (mm3)"]]["Tumor Volume (mm3)"].tolist()
my_infubinol = regimen_df.loc[regimen_df["Drug Regimen"] == "Infubinol", ["Tumor Volume (mm3)"]]["Tumor Volume (mm3)"].tolist()
my_ceftamin = regimen_df.loc[regimen_df["Drug Regimen"] == "Ceftamin", ["Tumor Volume (mm3)"]]["Tumor Volume (mm3)"].tolist()

my_COMBINED = [my_capomulin, my_ramicane, my_infubinol, my_ceftamin]
# my_COMBINED_df = pd.DataFrame({"Tumor Vol":my_COMBINED})
# my_COMBINED_df

print(f'Final tumor volume of each mouse across four of')
print(f'the most promising treatment regimens')

my_combined_df = pd.DataFrame({"Capomulin TumorVol (mm3)":my_capomulin, "Ceftamin TumorVol (mm3)":my_ceftamin, 
                               "Infubinol TumorVol (mm3)":my_infubinol, "Ramicane TumorVol (mm3)":my_ramicane})

my_combined_df
# Out:
# Final tumor volume of each mouse across four of
# the most promising treatment regimens
#     Capomulin TumorVol (mm3)  Ceftamin TumorVol (mm3)  \
# 0                  38.982878                62.999356
# 1                  38.939633                45.000000
# 2                  30.485985                56.057749
# 3                  37.074024                55.742829
# 4                  40.159220                48.722078
# 5                  47.685963                47.784682
# 6                  37.311846                61.849023
# 7                  38.125164                68.923185
# 8                  38.753265                67.748662
# 9                  41.483008                57.918381
# 10                 38.846876                46.784535
# 11                 28.430964                59.851956
# 12                 33.329098                64.299830
# 13                 46.539206                59.741901
# 14                 32.377357                61.433892
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse 
#across four regimens of interest 
plt.figure()

#Initial aesthetics to display the box plot
boxprops = dict(linestyle='-', linewidth=2.5, color='blue')
flierprops = dict(marker='o', markerfacecolor='red', markersize=9, linestyle='none')
medianprops = dict(linestyle='-', linewidth=2, color='blue')

#Box plot chart definition
ax = my_combined_df.boxplot(showmeans=True, flierprops=flierprops, medianprops=medianprops,
                           boxprops=boxprops)

## More aesthetics: custom x-axis labels and set title
ax.set_xticklabels(['Capomulin', 'Ceftamin', 'Infubinol', 'Ramicane'])
ax.set_title('Final Tumor Volume of each Mouse')

#print the plot
plt.show()

#Saving an image of this plot
plt.savefig("Images/10-Pyplot Box Chart Final Tumor Vol of Mice.png")
# Out:
# [Text(0, 0, 'Capomulin'),
#  Text(0, 0, 'Ceftamin'),
#  Text(0, 0, 'Infubinol'),
#  Text(0, 0, 'Ramicane')]
# Text(0.5, 1.0, 'Final Tumor Volume of each Mouse')

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin

#Locate drug regimen Capomulin for the combined data set

time_df = merged_data_df.loc[merged_data_df["Drug Regimen"] == "Capomulin"]

#Locate timepoints and tumor volume for mouse ID l509

mousel509 = time_df.loc[time_df["Mouse ID"] == "l509"]
mousel509
timel509 = mousel509["Timepoint"]
tumor_voll509 = mousel509["Tumor Volume (mm3)"]

#Define x and y axis to be plotted
x = timel509.tolist()
y = tumor_voll509.tolist()
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 231      l509          0           45.000000                 0    Capomulin
# 253      l509          5           45.851193                 0    Capomulin
# 539      l509         10           46.759074                 0    Capomulin
# 881      l509         15           47.488599                 1    Capomulin
# 982      l509         20           48.070452                 2    Capomulin
# 1146     l509         25           44.006257                 2    Capomulin
# 1414     l509         30           44.708055                 2    Capomulin
# 1499     l509         35           40.207289                 2    Capomulin
# 1723     l509         40           40.770813                 2    Capomulin
# 1771     l509         45           41.483008                 3    Capomulin
#
#        Sex  Age_months  Weight (g)
# 231   Male          17          21
# 253   Male          17          21
# ...

# %%
plt.plot(x, y, marker = '', linewidth = 1, color = "blue")
plt.title("Capomulin Treatment of mouse l509")
plt.xlabel("Tumor Volume (mm3)")
plt.ylabel("Timepoint (days)")
plt.xlim(-0.25,46)
plt.ylim(40,49)
plt.grid()
plt.show()

#Saving an image of this plot
plt.savefig("Images/12-Line Plot of Capomulin Treatment for Mouse l509.png")
# Out:
# Text(0.5, 1.0, 'Capomulin Treatment of mouse l509')
# Text(0.5, 0, 'Tumor Volume (mm3)')
# Text(0, 0.5, 'Timepoint (days)')
# (-0.25, 46)
# (40, 49)

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen 

#Define the variables to be plotted
mouse_capo_df = time_df.groupby(["Mouse ID"])
mouse_capo_df.count()

mouse_weight = mouse_capo_df["Weight (g)"].first()
av_tumor_vol = mouse_capo_df["Tumor Volume (mm3)"].mean()
av_tumor_vol

scatter_df = pd.DataFrame({"Weight (g)":mouse_weight, "Average Tumor Volume (mm3)":av_tumor_vol})
scatter_df
# Out:
#           Timepoint  Tumor Volume (mm3)  Metastatic Sites  Drug Regimen  Sex  \
# Mouse ID
# b128             10                  10                10            10   10
# b742             10                  10                10            10   10
# f966              5                   5                 5             5    5
# g288             10                  10                10            10   10
# g316             10                  10                10            10   10
# i557             10                  10                10            10   10
# i738             10                  10                10            10   10
# j119             10                  10                10            10   10
# j246              8                   8                 8             8    8
# l509             10                  10                10            10   10
# l897             10                  10                10            10   10
# ...

# %%
#Plotting the scatter chart
plt.scatter(mouse_weight, av_tumor_vol, marker='o', facecolor='red', alpha=0.75)

#Aesthetics
plt.title("Mouse Relationship of Weight vs. Average Tumor Volume")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.ylim(32, 48)
plt.grid()
plt.show()

#Saving an image of this plot
plt.savefig("Images/13-Scatter Plot of Mice Weight vs Average TumorVol.png")
# Out:
# Text(0.5, 1.0, 'Mouse Relationship of Weight vs. Average Tumor Volume')
# Text(0.5, 0, 'Weight (g)')
# Text(0, 0.5, 'Average Tumor Volume (mm3)')
# (32, 48)

# %%
# Add the linear regression equation and line to plot
#Additional dependy
from scipy.stats import linregress
#Variables x and y
x = mouse_weight
y = av_tumor_vol

# Get slope, intercept from linregress() to plot y' = intercept + slope*x
(slope, intercept, rvalue, pvalue, stderr) = linregress(x,y)

#Plotting the scatter chart
plt.scatter(x, y, marker='o', facecolor='red', alpha=0.75, label = "original data")

# Plot linear regression line.
y_pred = intercept + slope*x

plt.plot(x,y_pred, color="green")
print(f'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2)))

#Aesthetics
plt.title("Mouse Relationship of Weight vs. Average Tumor Volume")
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
plt.ylim(32, 48)
plt.grid()

print(f"The r-squared is: {rvalue}")
plt.show()
print(f'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2)))
# Out:
# y = 0.95x + 21.55
# Text(0.5, 1.0, 'Mouse Relationship of Weight vs. Average Tumor Volume')
# Text(0.5, 0, 'Weight (g)')
# Text(0, 0.5, 'Average Tumor Volume (mm3)')
# (32, 48)
# The r-squared is: 0.8419363424694718
# y = 0.95x + 21.55
